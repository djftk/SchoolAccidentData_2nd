# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel('./데이터/Data_final.xlsx')
data
# Out:
#          학교급  지역        교육청 설립유형 사고자구분 사고자성별 사고자학년       사고발생일 사고발생요일 사고발생시각  \
# 0        중학교  경기  안양과천교육지원청   공립  일반학생     남   1학년  2019-01-02      수  09:00
# 1       초등학교  경기  안양과천교육지원청   공립  일반학생     남   2학년  2019-01-02      수  08:50
# 2        중학교  경기    부천교육지원청   공립  일반학생     여   1학년  2019-01-02      수  10:20
# 3       초등학교  광주    서부교육지원청   공립  일반학생     여   2학년  2019-01-02      수  10:35
# 4        중학교  충북    청주교육지원청   공립  일반학생     남   2학년  2019-01-02      수  09:10
# ...      ...  ..        ...  ...   ...   ...   ...         ...    ...    ...
# 611765   중학교  제주  서귀포시교육지원청   공립  일반학생     여   2학년  2023-12-11      월  14:10
# 611766   중학교  제주   제주시교육지원청   공립  일반학생     남   1학년  2023-12-08      금  13:20
# 611767   중학교  제주   제주시교육지원청   공립  일반학생     여   3학년  2023-12-04      월  09:20
# 611768   중학교  제주   제주시교육지원청   공립  일반학생     남   1학년  2023-12-13      수  12:25
# 611769   중학교  제주   제주시교육지원청   공립  일반학생     남   1학년  2023-11-30      목  15:50
#
#                사고시간  사고장소    사고부위     사고형태    사고당시활동  \
# 0              수업시간  부속시설      다리  낙상-미끄러짐      기타운동
# 1               등하교    통로  치아(구강)   낙상-넘어짐     보행/주행
# 2              체육수업  부속시설       손       기타      구기운동
# 3       휴식시간 및 청소시간   운동장  머리(두부)   낙상-넘어짐     장난/놀이
# 4              체육수업  부속시설       발  낙상-미끄러짐     보행/주행
# ...             ...   ...     ...      ...       ...
# 611765         쉬는시간    교실       팔  물리적힘 노출     장난/놀이
# 611766         쉬는시간    통로      다리  사람과의 충돌  식사/수면/휴식
# 611767         특별활동   운동장       손  물리적힘 노출      구기운동
# 611768         식사시간  부속시설       발       낙상     장난/놀이
# 611769         체육활동   운동장    복합부위  물리적힘 노출      구기운동
#
#                                  사고매개물  사고연도  사고월  사고일        나이
# 0                      건물(문/창문/바닥/벽 등)  2019    1    2       중학생
# 1                      건물(문/창문/바닥/벽 등)  2019    1    2  초등학생 저학년
# 2                                   기타  2019    1    2       중학생
# 3                       자연(사람/동물/식물 등)  2019    1    2  초등학생 저학년
# 4                      건물(문/창문/바닥/벽 등)  2019    1    2       중학생
# ...                                ...   ...  ...  ...       ...
# 611765                 건물(문/창문/바닥/벽 등)  2023   12   11       중학생
# 611766                  자연(사람/동물/식물 등)  2023   12    8       중학생
# 611767  운동(놀이)용 장비/기구(공/운동기구/운동장 기구 등)  2023   12    4       중학생
# 611768                  자연(사람/동물/식물 등)  2023   12   13       중학생
# 611769  운동(놀이)용 장비/기구(공/운동기구/운동장 기구 등)  2023   11   30       중학생
#
# [611770 rows x 20 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 611770 entries, 0 to 611769
# Data columns (total 20 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   학교급     611770 non-null  object
#  1   지역      611770 non-null  object
#  2   교육청     611770 non-null  object
#  3   설립유형    611770 non-null  object
#  4   사고자구분   611770 non-null  object
#  5   사고자성별   611770 non-null  object
#  6   사고자학년   610388 non-null  object
#  7   사고발생일   611770 non-null  object
#  8   사고발생요일  611770 non-null  object
#  9   사고발생시각  611770 non-null  object
#  10  사고시간    611770 non-null  object
#  11  사고장소    611770 non-null  object
#  12  사고부위    611770 non-null  object
#  13  사고형태    611770 non-null  object
#  14  사고당시활동  611770 non-null  object
#  15  사고매개물   611770 non-null  object
#  16  사고연도    611770 non-null  int64
#  17  사고월     611770 non-null  int64
#  18  사고일     611770 non-null  int64
#  19  나이      611770 non-null  object
# dtypes: int64(3), object(17)
# memory usage: 93.3+ MB

# %%
data.isnull().sum()
# Out:
# 학교급          0
# 지역           0
# 교육청          0
# 설립유형         0
# 사고자구분        0
# 사고자성별        0
# 사고자학년     1382
# 사고발생일        0
# 사고발생요일       0
# 사고발생시각       0
# 사고시간         0
# 사고장소         0
# 사고부위         0
# 사고형태         0
# 사고당시활동       0
# 사고매개물        0
# 사고연도         0
# 사고월          0
# 사고일          0
# 나이           0
# dtype: int64

# %%
data.describe()
# Out:
#                 사고연도            사고월            사고일
# count  611770.000000  611770.000000  611770.000000
# mean     2021.343533       7.351096      16.103653
# std         1.526790       3.018673       8.583035
# min      2019.000000       1.000000       1.000000
# 25%      2020.000000       5.000000       9.000000
# 50%      2022.000000       7.000000      16.000000
# 75%      2023.000000      10.000000      23.000000
# max      2023.000000      12.000000      31.000000

# %%
from sklearn.preprocessing import LabelEncoder

# 라벨 인코더 생성 및 적용
label_encoders = {}
for column in data.select_dtypes(include=['object']).columns:
    label_encoders[column] = LabelEncoder()
    data[column] = label_encoders[column].fit_transform(data[column].astype(str))

# %%
from matplotlib import font_manager, rc

# 한글 폰트 설정
font_path = r"C:\Users\USER\Desktop\학교안전사고 데이터\데이터\nanum-all\나눔 글꼴\나눔고딕\NanumFontSetup_TTF_GOTHIC\NanumGothic.ttf"  # 폰트 파일 경로 설정
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

# %%
corrmat = data.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
g = sns.heatmap(data[top_corr_features].corr(), annot=True, cmap="RdYlGn")
print(g)
# Out:
# C:\Users\USER\miniconda3\envs\data_school\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.draw()
# Axes(0.125,0.11;0.62x0.77)
# C:\Users\USER\miniconda3\envs\data_school\lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\USER\miniconda3\envs\data_school\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
